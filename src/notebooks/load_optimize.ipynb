# %% [markdown]
# # Init

# %%
import os, sys

ROOT_DIR = '../..'
sys.path.append(ROOT_DIR)
os.chdir(ROOT_DIR)

from dotenv import load_dotenv
load_dotenv('.env')

DATAPATH = os.getenv("DATAPATH")

import pandas as pd

# %%
filenames = [f for f in os.listdir(DATAPATH) if f.endswith('.csv')]
filenames
# Out:
# ['amostra_projeto1.csv',
#  'amostra_projeto_3.csv',
#  'projeto_4.csv',
#  'amostra_projeto_2.csv']

# %% [markdown]
# # Carga e otimização

# %%
for filename in filenames:
    filepath = os.path.join(DATAPATH, filename)
    # !wc -l $filepath
    # !head -n 20 $filepath
    print()
    # !tail $filepath
    print('\n')
# Out:
# 163 src/datasets/amostra_projeto1.csv
# DADOS,,,,,,,,,,,,,
# Titulo,Projeto 1 - Wa,,,,,,,,,,,,
# Tipologia,Térrea,,,,,,,,,,,,
# Área Terreno,"485,00",,,,,,,,,,,,
# Área Construída,"246,63",,,,,,,,,,,,
# Área Fundação,"237,98",,,,,,,,,,,,
# Área Fachada,"597,88",,,,,,,,,,,,
# Área Parede,"615,86",,,,,,,,,,,,
# Qtde BWCs,"5,00",,,,,,,,,,,,
# ,,,,,,,,,,,,,
# TABELA DE ORÇAMENTO,,,,,,,,,,,,,
# Item,Referência,Tipo,Código,Descrição,Unid.,Quantidade,BDI,Preço Material,,Preço Execução,,Preço,
# ,,,,,,,,Unitário,Total,Unitário,Total,Unitário,Total
# 1.,,,,ETAPAS PRE OBRA,,,"0,0%",,,," R$  8.086,25 ",," R$  8.086,25 "
# 1.1.,,,,SONDAGEM,,,"0,0%",,,," R$  3.000,00 ",," R$  3.000,00 "
# 1.1.1,MKS_COMPOSICOES,COMPOSICAO,CMP_INF-SON,SONDAGEM,VB,1,"0,0%",,," R$  3.000,00 "," R$  3.000,00 "," R$  3.000,00 "," R$  3.000,00 "
# 1.2.,,,,LEVANTAMENTO TOPOGRAFICO,,,"0,0%",,,," R$  1.200,00 ",," R$  1.200,00 "
# 1.2.1,MKS_COMPOSICOES,COMPOSICAO,CMP_INF-LVT,LEVANTAMENTO TOPOGRAFICO,VB,1,"0,0%",,," R$  1.200,00 "," R$  1.200,00 "," R$  1.200,00 "," R$  1.200,00 "
# 1.3.,,,,TAXAS DE APROVACAO,,,"0,0%",,,," R$  3.708,69 ",," R$  3.708,69 "
# 1.3.1,MKS_COMPOSICOES,COMPOSICAO,CMP_EPO-TAX-APR,APROVACAO DE PROJETOS E TAXAS,VB,1,"0,0%",,," R$  2.000,00 "," R$  2.000,00 "," R$  2.000,00 "," R$  2.000,00 "
#
# 14.4.,,,,LIMPEZA FINAL DE OBRA,,,"0,0%",,,," R$  3.450,00 ",," R$  3.450,00 "
# 14.4.1,MKS_COMPOSICOES,COMPOSICAO,CMP_LAF-LPZ-FNL-OBR,LIMPEZA FINAL DE OBRA,M2,300,"0,0%",,," R$  11,50 "," R$  3.450,00 "," R$  11,50 "," R$  3.450,00 "
# 15.,,,,FINALIZACAO DA OBRA,,,"11,6%",,,," R$  1,12 ",," R$  1,12 "
# 15.1.,,,,FINALIZACAO OBRA,,,"11,6%",,,," R$  1,12 ",," R$  1,12 "
# 15.1.1,MKS_COMPOSICOES,COMPOSICAO,CMP_FNO-FOR-ENT,"FORMALIZACAO DA ENTREGA VISTORIA, ACEITE",VB,1,"11,6%",,," R$  1,12 "," R$  1,12 "," R$  1,12 "," R$  1,12 "
# 16.,,,,FORMALIZACAO DA ENTREGA,,,"0,0%",,,," R$  912,85 ",," R$  912,85 "
# 16.1.,,,,HABITE-SE E AVERBACAO,,,"0,0%",,,," R$  912,85 ",," R$  912,85 "
# 16.1.1,MKS_COMPOSICOES,COMPOSICAO,CMP_EPO-TAX-AVR,TAXA AVERBACAO,VB,1,"0,0%",,," R$  502,85 "," R$  502,85 "," R$  502,85 "," R$  502,85 "
# 16.1.2,MKS_COMPOSICOES,COMPOSICAO,CMP_EPO-TAX-HBT,TAXA HABITE-SE PREFEITURA,VB,1,"0,0%",,," R$  150,00 "," R$  150,00 "," R$  150,00 "," R$  150,00 "
# 16.1.3,MKS_COMPOSICOES,COMPOSICAO,CMP_EPO-TAX-VCA,TAXA VISTORIA CONCESSIONARIA DE AGUA,VB,1,"0,0%",,," R$  260,00 "," R$  260,00 "," R$  260,00 "," R$  260,00 "
#
# 168 src/datasets/amostra_projeto_3.csv
# DADOS,,,,,,,,,,,,,
# Titulo,Projeto 3 - Je2,,,,,,,,,,,,
# Tipologia,Sobrado,,,,,,,,,,,,
# Área Terreno,"500,00",,,,,,,,,,,,
# Área Construída,"425,00",,,,,,,,,,,,
# Área Fundação,"378,31",,,,,,,,,,,,
# Área Fachada,"521,67",,,,,,,,,,,,
# Área Parede,"581,76",,,,,,,,,,,,
# Qtde BWCs,"6,00",,,,,,,,,,,,
# ,,,,,,,,,,,,,
# TABELA DE ORÇAMENTO,,,,,,,,,,,,,
# Item,Referência,Tipo,Código,Descrição,Unid.,Quantidade,BDI,Preço Material,,Preço Execução,,Preço,
# ,,,,,,,, Unitário, Total, Unitário, Total, Unitário, Total
# 1.,,,,ETAPAS PRE OBRA,,,"0,0%",,,," R$  9.286,25 ",," R$  9.286,25 "
# 1.1.,,,,SONDAGEM,,,"0,0%",,,," R$  3.000,00 ",," R$  3.000,00 "
# 1.1.1,MKS_COMPOSICOES,COMPOSICAO,CMP_INF-SON,SONDAGEM,VB,1,"0,0%",,," R$  3.000,00 "," R$  3.000,00 "," R$  3.000,00 "," R$  3.000,00 "
# 1.2.,,,,LEVANTAMENTO TOPOGRAFICO,,,"0,0%",,,," R$  2.400,00 ",," R$  2.400,00 "
# 1.2.1,MKS_COMPOSICOES,COMPOSICAO,CMP_INF-LVT,LEVANTAMENTO TOPOGRAFICO,VB,2,"0,0%",,," R$  1.200,00 "," R$  2.400,00 "," R$  1.200,00 "," R$  2.400,00 "
# 1.3.,,,,RESPONSABILIDADE TECNICA,,,"0,0%",,,," R$  177,56 ",," R$  177,56 "
# 1.3.1,MKS_COMPOSICOES,COMPOSICAO,CMP_EPO-TAX-ART,TAXA ART,VB,2,"0,0%",,," R$  88,78 "," R$  177,56 "," R$  88,78 "," R$  177,56 "
#
# 14.4.,,,,LIMPEZA FINAL DE OBRA,,,"0,0%",,,," R$  6.900,00 ",," R$  6.900,00 "
# 14.4.1,MKS_COMPOSICOES,COMPOSICAO,CMP_LAF-LPZ-FNL-OBR,LIMPEZA FINAL DE OBRA,M2,600,"0,0%",,," R$  11,50 "," R$  6.900,00 "," R$  11,50 "," R$  6.900,00 "
# 15.,,,,FINALIZACAO DA OBRA,,,"11,6%",,,," R$  1,12 ",," R$  1,12 "
# 15.1.,,,,FINALIZACAO OBRA,,,"11,6%",,,," R$  1,12 ",," R$  1,12 "
# 15.1.1,MKS_COMPOSICOES,COMPOSICAO,CMP_FNO-FOR-ENT,"FORMALIZACAO DA ENTREGA VISTORIA, ACEITE",VB,1,"11,6%",,," R$  1,12 "," R$  1,12 "," R$  1,12 "," R$  1,12 "
# 16.,,,,FORMALIZACAO DA ENTREGA,,,"0,0%",,,," R$  912,85 ",," R$  912,85 "
# 16.1.,,,,HABITE-SE E AVERBACAO,,,"0,0%",,,," R$  912,85 ",," R$  912,85 "
# 16.1.1,MKS_COMPOSICOES,COMPOSICAO,CMP_EPO-TAX-AVR,TAXA AVERBACAO,VB,1,"0,0%",,," R$  502,85 "," R$  502,85 "," R$  502,85 "," R$  502,85 "
# 16.1.2,MKS_COMPOSICOES,COMPOSICAO,CMP_EPO-TAX-HBT,TAXA HABITE-SE PREFEITURA,VB,1,"0,0%",,," R$  150,00 "," R$  150,00 "," R$  150,00 "," R$  150,00 "
# 16.1.3,MKS_COMPOSICOES,COMPOSICAO,CMP_EPO-TAX-VCA,TAXA VISTORIA CONCESSIONARIA DE AGUA,VB,1,"0,0%",,," R$  260,00 "," R$  260,00 "," R$  260,00 "," R$  260,00 "
#
# 8 src/datasets/projeto_4.csv
# DADOS,
# Titulo,Projeto 4 - Je3
# Tipologia,Sobrado
# Área Terreno,"250,00"
# Área Construída,"257,00"
# Área Fundação,"221,36"
# Área Fachada,"430,11"
# Área Parede,"547,27"
# Qtde BWCs,"6,00"
# DADOS,
# Titulo,Projeto 4 - Je3
# Tipologia,Sobrado
# Área Terreno,"250,00"
# Área Construída,"257,00"
# Área Fundação,"221,36"
# Área Fachada,"430,11"
# Área Parede,"547,27"
# Qtde BWCs,"6,00"
#
# 173 src/datasets/amostra_projeto_2.csv
# DADOS,,,,,,,,,,,,,
# Titulo,Projeto 2 - Ca,,,,,,,,,,,,
# Tipologia,Sobrado,,,,,,,,,,,,
# Área Terreno,"300,00",,,,,,,,,,,,
# Área Construída,"249,24",,,,,,,,,,,,
# Área Fundação,"161,55",,,,,,,,,,,,
# Área Fachada,"747,17",,,,,,,,,,,,
# Área Parede,"662,06",,,,,,,,,,,,
# Qtde BWCs,"4,00",,,,,,,,,,,,
# ,,,,,,,,,,,,,
# TABELA DE ORÇAMENTO,,,,,,,,,,,,,
# Item,Referência,Tipo,Código,Descrição,Unid.,Quantidade,BDI,Preço Material,,Preço Execução,,Preço,
# ,,,,,,,,Unitário,Total,Unitário,Total,Unitário,Total
# 1.,,,, ,,,"0,0%",,,," R$  8.086,25 ",," R$  8.086,25 "
# 1.1.,,,,SONDAGEM,,,"0,0%",,,," R$  3.000,00 ",," R$  3.000,00 "
# 1.1.1,MKS_COMPOSICOES,COMPOSICAO,CMP_INF-SON,SONDAGEM,VB,1,"0,0%",,," R$  3.000,00 "," R$  3.000,00 "," R$  3.000,00 "," R$  3.000,00 "
# 1.2.,,,,LEVANTAMENTO TOPOGRAFICO,,,"0,0%",,,," R$  1.200,00 ",," R$  1.200,00 "
# 1.2.1,MKS_COMPOSICOES,COMPOSICAO,CMP_INF-LVT,LEVANTAMENTO TOPOGRAFICO,VB,1,"0,0%",,," R$  1.200,00 "," R$  1.200,00 "," R$  1.200,00 "," R$  1.200,00 "
# 1.3.,,,,TAXAS DE APROVACAO,,,"0,0%",,,," R$  3.708,69 ",," R$  3.708,69 "
# 1.3.1,MKS_COMPOSICOES,COMPOSICAO,CMP_EPO-TAX-APR,APROVACAO DE PROJETOS E TAXAS,VB,1,"0,0%",,," R$  2.000,00 "," R$  2.000,00 "," R$  2.000,00 "," R$  2.000,00 "
#
# 14.4.,,,,LIMPEZA FINAL DE OBRA,,,"0,0%",,,," R$  2.875,00 ",," R$  2.875,00 "
# 14.4.1,MKS_COMPOSICOES,COMPOSICAO,CMP_LAF-LPZ-FNL-OBR,LIMPEZA FINAL DE OBRA,M2,250,"0,0%",,," R$  11,50 "," R$  2.875,00 "," R$  11,50 "," R$  2.875,00 "
# 15.,,,,FINALIZACAO DA OBRA,,,"11,6%",,,," R$  1,12 ",," R$  1,12 "
# 15.1.,,,,FINALIZACAO OBRA,,,"11,6%",,,," R$  1,12 ",," R$  1,12 "
# 15.1.1,MKS_COMPOSICOES,COMPOSICAO,CMP_FNO-FOR-ENT,"FORMALIZACAO DA ENTREGA VISTORIA, ACEITE",VB,1,"11,6%",,," R$  1,12 "," R$  1,12 "," R$  1,12 "," R$  1,12 "
# 16.,,,,FORMALIZACAO DA ENTREGA,,,"0,0%",,,," R$  912,85 ",," R$  912,85 "
# 16.1.,,,,HABITE-SE E AVERBACAO,,,"0,0%",,,," R$  912,85 ",," R$  912,85 "
# 16.1.1,MKS_COMPOSICOES,COMPOSICAO,CMP_EPO-TAX-AVR,TAXA AVERBACAO,VB,1,"0,0%",,," R$  502,85 "," R$  502,85 "," R$  502,85 "," R$  502,85 "
# 16.1.2,MKS_COMPOSICOES,COMPOSICAO,CMP_EPO-TAX-HBT,TAXA HABITE-SE PREFEITURA,VB,1,"0,0%",,," R$  150,00 "," R$  150,00 "," R$  150,00 "," R$  150,00 "
# 16.1.3,MKS_COMPOSICOES,COMPOSICAO,CMP_EPO-TAX-VCA,TAXA VISTORIA CONCESSIONARIA DE AGUA,VB,1,"0,0%",,," R$  260,00 "," R$  260,00 "," R$  260,00 "," R$  260,00 "

# %% [markdown]
# ## Features

# %%
def transpose_dataframe(df:pd.DataFrame):
    df = df.set_index('variable').T
    df = df.reset_index(drop=True)
    df.columns.name = None
    return df

# %%
df_features = pd.DataFrame(data=None)
for filename in filenames:
    df = pd.read_csv(os.path.join(DATAPATH, filename), skiprows=1, nrows=8, usecols=[0,1], header=None, names=['variable', 'value'])
    df = transpose_dataframe(df)
    df['filename'] = filename
    df_features = pd.concat([df_features, df])
df_features = df_features.sort_values(by='Titulo').reset_index(drop=True).reset_index(names=['id_project'])
df_features
# Out:
#    id_project           Titulo Tipologia Área Terreno Área Construída  \
# 0           0   Projeto 1 - Wa    Térrea       485,00          246,63
# 1           1   Projeto 2 - Ca   Sobrado       300,00          249,24
# 2           2  Projeto 3 - Je2   Sobrado       500,00          425,00
# 3           3  Projeto 4 - Je3   Sobrado       250,00          257,00
#
#   Área Fundação Área Fachada Área Parede Qtde BWCs               filename
# 0        237,98       597,88      615,86      5,00   amostra_projeto1.csv
# 1        161,55       747,17      662,06      4,00  amostra_projeto_2.csv
# 2        378,31       521,67      581,76      6,00  amostra_projeto_3.csv
# 3        221,36       430,11      547,27      6,00          projeto_4.csv

# %%
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_project       4 non-null      int64
#  1   Titulo           4 non-null      object
#  2   Tipologia        4 non-null      object
#  3   Área Terreno     4 non-null      object
#  4   Área Construída  4 non-null      object
#  5   Área Fundação    4 non-null      object
#  6   Área Fachada     4 non-null      object
#  7   Área Parede      4 non-null      object
#  8   Qtde BWCs        4 non-null      object
#  9   filename         4 non-null      object
# dtypes: int64(1), object(9)
# memory usage: 452.0+ bytes

# %%
numeric_columns = df_features.columns[3:-1]
for col in numeric_columns:
    df_features[col] = df_features[col].str.replace('.', '').str.replace(',', '.')
    df_features[col] = pd.to_numeric(df_features[col])
df_features
# Out:
#    id_project           Titulo Tipologia  Área Terreno  Área Construída  \
# 0           0   Projeto 1 - Wa    Térrea         485.0           246.63
# 1           1   Projeto 2 - Ca   Sobrado         300.0           249.24
# 2           2  Projeto 3 - Je2   Sobrado         500.0           425.00
# 3           3  Projeto 4 - Je3   Sobrado         250.0           257.00
#
#    Área Fundação  Área Fachada  Área Parede  Qtde BWCs               filename
# 0         237.98        597.88       615.86        5.0   amostra_projeto1.csv
# 1         161.55        747.17       662.06        4.0  amostra_projeto_2.csv
# 2         378.31        521.67       581.76        6.0  amostra_projeto_3.csv
# 3         221.36        430.11       547.27        6.0          projeto_4.csv

# %%
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_project       4 non-null      int64
#  1   Titulo           4 non-null      object
#  2   Tipologia        4 non-null      object
#  3   Área Terreno     4 non-null      float64
#  4   Área Construída  4 non-null      float64
#  5   Área Fundação    4 non-null      float64
#  6   Área Fachada     4 non-null      float64
#  7   Área Parede      4 non-null      float64
#  8   Qtde BWCs        4 non-null      float64
#  9   filename         4 non-null      object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 452.0+ bytes

# %%
from unicodedata import normalize


def transliterate(string):
  words = normalize('NFKD', string).encode('ASCII','ignore').decode('ASCII').split()
  return '_'.join(words)

def parse_columns(columns):
  columns = transliterate(', '.join(columns)).lower().split(',')
  return [col.strip('_') for col in columns]

# %%
df_features.columns = parse_columns(df_features.columns)
df_features
# Out:
#    id_project           titulo tipologia  area_terreno  area_construida  \
# 0           0   Projeto 1 - Wa    Térrea         485.0           246.63
# 1           1   Projeto 2 - Ca   Sobrado         300.0           249.24
# 2           2  Projeto 3 - Je2   Sobrado         500.0           425.00
# 3           3  Projeto 4 - Je3   Sobrado         250.0           257.00
#
#    area_fundacao  area_fachada  area_parede  qtde_bwcs               filename
# 0         237.98        597.88       615.86        5.0   amostra_projeto1.csv
# 1         161.55        747.17       662.06        4.0  amostra_projeto_2.csv
# 2         378.31        521.67       581.76        6.0  amostra_projeto_3.csv
# 3         221.36        430.11       547.27        6.0          projeto_4.csv

# %%
df_features.to_parquet(os.path.join(DATAPATH, 'staged', 'features.parquet'))

# %% [markdown]
# ## Target

# %%
def merge_columns(df:pd.DataFrame):
    columns_to_rename = {
        "Preço Material": 'Preço Material Unitário',
        'Unnamed: 9': 'Preço Material Total',
        'Preço Execução': 'Preço Execução Unitário',
        'Unnamed: 11': 'Preço Execução Total',
        'Preço': 'Preço Unitário',
        'Unnamed: 13': 'Preço Total',
    }
    df = df.rename(columns=columns_to_rename)
    df = df.drop(0).reset_index(drop=True)
    return df

# %%
df_target = pd.DataFrame(data=None)
for filename in filenames:
    if filename == 'projeto_4.csv':
        continue
    df = pd.read_csv(os.path.join(DATAPATH, filename), skiprows=11)
    df = merge_columns(df)
    df['id_project'] = df_features.query('filename == @filename')['id_project'].item()
    df_target = pd.concat([df_target, df])
df_target.columns = parse_columns(df_target.columns)
df_target
# Out:
#        item       referencia        tipo           codigo  \
# 0        1.              NaN         NaN              NaN
# 1      1.1.              NaN         NaN              NaN
# 2     1.1.1  MKS_COMPOSICOES  COMPOSICAO      CMP_INF-SON
# 3      1.2.              NaN         NaN              NaN
# 4     1.2.1  MKS_COMPOSICOES  COMPOSICAO      CMP_INF-LVT
# ..      ...              ...         ...              ...
# 156     16.              NaN         NaN              NaN
# 157   16.1.              NaN         NaN              NaN
# 158  16.1.1  MKS_COMPOSICOES  COMPOSICAO  CMP_EPO-TAX-AVR
# 159  16.1.2  MKS_COMPOSICOES  COMPOSICAO  CMP_EPO-TAX-HBT
# 160  16.1.3  MKS_COMPOSICOES  COMPOSICAO  CMP_EPO-TAX-VCA
#
#                                 descricao unid. quantidade   bdi  \
# 0                         ETAPAS PRE OBRA   NaN        NaN  0,0%
# 1                                SONDAGEM   NaN        NaN  0,0%
# 2                                SONDAGEM    VB          1  0,0%
# 3                LEVANTAMENTO TOPOGRAFICO   NaN        NaN  0,0%
# 4                LEVANTAMENTO TOPOGRAFICO    VB          1  0,0%
# ..                                    ...   ...        ...   ...
# 156               FORMALIZACAO DA ENTREGA   NaN        NaN  0,0%
# 157                 HABITE-SE E AVERBACAO   NaN        NaN  0,0%
# 158                        TAXA AVERBACAO    VB          1  0,0%
# 159             TAXA HABITE-SE PREFEITURA    VB          1  0,0%
# 160  TAXA VISTORIA CONCESSIONARIA DE AGUA    VB          1  0,0%
#
#     preco_material_unitario preco_material_total preco_execucao_unitario  \
# 0                       NaN                  NaN                     NaN
# 1                       NaN                  NaN                     NaN
# 2                       NaN                  NaN           R$  3.000,00
# 3                       NaN                  NaN                     NaN
# 4                       NaN                  NaN           R$  1.200,00
# ..                      ...                  ...                     ...
# 156                     NaN                  NaN                     NaN
# 157                     NaN                  NaN                     NaN
# 158                     NaN                  NaN             R$  502,85
# 159                     NaN                  NaN             R$  150,00
# 160                     NaN                  NaN             R$  260,00
#
#     preco_execucao_total  preco_unitario     preco_total  id_project
# 0          R$  8.086,25              NaN   R$  8.086,25            0
# 1          R$  3.000,00              NaN   R$  3.000,00            0
# 2          R$  3.000,00    R$  3.000,00    R$  3.000,00            0
# 3          R$  1.200,00              NaN   R$  1.200,00            0
# 4          R$  1.200,00    R$  1.200,00    R$  1.200,00            0
# ..                   ...             ...             ...         ...
# 156          R$  912,85              NaN     R$  912,85            1
# 157          R$  912,85              NaN     R$  912,85            1
# 158          R$  502,85      R$  502,85      R$  502,85            1
# 159          R$  150,00      R$  150,00      R$  150,00            1
# 160          R$  260,00      R$  260,00      R$  260,00            1
#
# [468 rows x 15 columns]

# %%
df_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 468 entries, 0 to 160
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   item                     468 non-null    object
#  1   referencia               280 non-null    object
#  2   tipo                     280 non-null    object
#  3   codigo                   280 non-null    object
#  4   descricao                468 non-null    object
#  5   unid.                    280 non-null    object
#  6   quantidade               280 non-null    object
#  7   bdi                      468 non-null    object
#  8   preco_material_unitario  220 non-null    object
#  9   preco_material_total     367 non-null    object
#  10  preco_execucao_unitario  208 non-null    object
#  11  preco_execucao_total     377 non-null    object
#  12  preco_unitario           280 non-null    object
#  13  preco_total              468 non-null    object
#  14  id_project               468 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 58.5+ KB

# %%
def parse_price_columns(df:pd.DataFrame, price_columns):
    for col in price_columns:
        df[col] = df[col].str.strip().str.split(r'\s').str[-1]
        df[col] = df[col].str.replace('.', '').str.replace(',', '.')
        df[col] = pd.to_numeric(df[col])
    return df

price_columns = [col for col in df_target.columns if 'preco' in col]
df_target = parse_price_columns(df_target, price_columns)
df_target['quantidade'] = pd.to_numeric(df_target['quantidade'].str.replace(',', '.'))
df_target['bdi'] = df_target['bdi'].str.replace('%', '').str.replace(',', '.')
df_target['bdi'] = pd.to_numeric(df_target['bdi'])
df_target.reset_index(drop=True, inplace=True)
df_target
# Out:
#        item       referencia        tipo           codigo  \
# 0        1.              NaN         NaN              NaN
# 1      1.1.              NaN         NaN              NaN
# 2     1.1.1  MKS_COMPOSICOES  COMPOSICAO      CMP_INF-SON
# 3      1.2.              NaN         NaN              NaN
# 4     1.2.1  MKS_COMPOSICOES  COMPOSICAO      CMP_INF-LVT
# ..      ...              ...         ...              ...
# 463     16.              NaN         NaN              NaN
# 464   16.1.              NaN         NaN              NaN
# 465  16.1.1  MKS_COMPOSICOES  COMPOSICAO  CMP_EPO-TAX-AVR
# 466  16.1.2  MKS_COMPOSICOES  COMPOSICAO  CMP_EPO-TAX-HBT
# 467  16.1.3  MKS_COMPOSICOES  COMPOSICAO  CMP_EPO-TAX-VCA
#
#                                 descricao unid.  quantidade  bdi  \
# 0                         ETAPAS PRE OBRA   NaN         NaN  0.0
# 1                                SONDAGEM   NaN         NaN  0.0
# 2                                SONDAGEM    VB         1.0  0.0
# 3                LEVANTAMENTO TOPOGRAFICO   NaN         NaN  0.0
# 4                LEVANTAMENTO TOPOGRAFICO    VB         1.0  0.0
# ..                                    ...   ...         ...  ...
# 463               FORMALIZACAO DA ENTREGA   NaN         NaN  0.0
# 464                 HABITE-SE E AVERBACAO   NaN         NaN  0.0
# 465                        TAXA AVERBACAO    VB         1.0  0.0
# 466             TAXA HABITE-SE PREFEITURA    VB         1.0  0.0
# 467  TAXA VISTORIA CONCESSIONARIA DE AGUA    VB         1.0  0.0
#
#      preco_material_unitario  preco_material_total  preco_execucao_unitario  \
# 0                        NaN                   NaN                      NaN
# 1                        NaN                   NaN                      NaN
# 2                        NaN                   NaN                  3000.00
# 3                        NaN                   NaN                      NaN
# 4                        NaN                   NaN                  1200.00
# ..                       ...                   ...                      ...
# 463                      NaN                   NaN                      NaN
# 464                      NaN                   NaN                      NaN
# 465                      NaN                   NaN                   502.85
# 466                      NaN                   NaN                   150.00
# 467                      NaN                   NaN                   260.00
#
#      preco_execucao_total  preco_unitario  preco_total  id_project
# 0                 8086.25             NaN      8086.25           0
# 1                 3000.00             NaN      3000.00           0
# 2                 3000.00         3000.00      3000.00           0
# 3                 1200.00             NaN      1200.00           0
# 4                 1200.00         1200.00      1200.00           0
# ..                    ...             ...          ...         ...
# 463                912.85             NaN       912.85           1
# 464                912.85             NaN       912.85           1
# 465                502.85          502.85       502.85           1
# 466                150.00          150.00       150.00           1
# 467                260.00          260.00       260.00           1
#
# [468 rows x 15 columns]

# %%
df_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468 entries, 0 to 467
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   item                     468 non-null    object
#  1   referencia               280 non-null    object
#  2   tipo                     280 non-null    object
#  3   codigo                   280 non-null    object
#  4   descricao                468 non-null    object
#  5   unid.                    280 non-null    object
#  6   quantidade               280 non-null    float64
#  7   bdi                      468 non-null    float64
#  8   preco_material_unitario  220 non-null    float64
#  9   preco_material_total     367 non-null    float64
#  10  preco_execucao_unitario  208 non-null    float64
#  11  preco_execucao_total     377 non-null    float64
#  12  preco_unitario           280 non-null    float64
#  13  preco_total              468 non-null    float64
#  14  id_project               468 non-null    int64
# dtypes: float64(8), int64(1), object(6)
# memory usage: 55.0+ KB

# %%
df_target.to_parquet(os.path.join(DATAPATH, 'staged', 'target.parquet'))
